# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Repeat with last year's data
#
# ### Load the data

# %%
import pandas as pd

trade_last_year = pd.read_excel("export_2020m1.xlsx", skiprows=1, index_col=0, nrows=7)
trade_last_year
# Out:
#                       Canada       France      Germany        Italy  \
# Canada                   NaN   259.774344   356.288051   158.939284
# France            269.969993          NaN  6440.928402  3525.584930
# Germany           931.950594  9628.673888          NaN  6253.252577
# Italy             385.370044  4422.526669  5280.943382          NaN
# Japan             742.191653   482.307729  1487.667310   373.958913
# United Kingdom    547.707600  2434.150113  4016.820126   984.401990
# United States   22550.409387  3494.204301  4718.306603  1742.348778
#
#                       Japan  United Kingdom  United States
# Canada           773.170192     1458.702675   26820.721998
# France           544.497147     2685.976457    3219.695959
# Germany         1863.955690     6717.742877   10086.173941
# Italy            718.988403     2248.973697    4146.895775
# Japan                   NaN     1331.326120    9664.659178
# United Kingdom   538.725446             NaN    6139.224086
# United States   5454.467853     5832.579169            NaN

# %% [markdown]
# ## Create the network
#
# We first convert the matrix data into pair data

# %%
trade_last_year = pd.melt(trade_last_year.reset_index(), id_vars='index')
trade_last_year.columns = ['export_country', 'import_country', 'value']

# %%
trade_last_year.dropna(inplace=True)
trade_last_year
# Out:
#     export_country  import_country         value
# 1           France          Canada    269.969993
# 2          Germany          Canada    931.950594
# 3            Italy          Canada    385.370044
# 4            Japan          Canada    742.191653
# 5   United Kingdom          Canada    547.707600
# 6    United States          Canada  22550.409387
# 7           Canada          France    259.774344
# 9          Germany          France   9628.673888
# 10           Italy          France   4422.526669
# 11           Japan          France    482.307729
# 12  United Kingdom          France   2434.150113
# 13   United States          France   3494.204301
# 14          Canada         Germany    356.288051
# 15          France         Germany   6440.928402
# 17           Italy         Germany   5280.943382
# 18           Japan         Germany   1487.667310
# 19  United Kingdom         Germany   4016.820126
# 20   United States         Germany   4718.306603
# 21          Canada           Italy    158.939284
# 22          France           Italy   3525.584930
# 23         Germany           Italy   6253.252577
# 25           Japan           Italy    373.958913
# 26  United Kingdom           Italy    984.401990
# 27   United States           Italy   1742.348778
# 28          Canada           Japan    773.170192
# 29          France           Japan    544.497147
# 30         Germany           Japan   1863.955690
# 31           Italy           Japan    718.988403
# 33  United Kingdom           Japan    538.725446
# 34   United States           Japan   5454.467853
# 35          Canada  United Kingdom   1458.702675
# 36          France  United Kingdom   2685.976457
# 37         Germany  United Kingdom   6717.742877
# 38           Italy  United Kingdom   2248.973697
# 39           Japan  United Kingdom   1331.326120
# 41   United States  United Kingdom   5832.579169
# 42          Canada   United States  26820.721998
# 43          France   United States   3219.695959
# 44         Germany   United States  10086.173941
# 45           Italy   United States   4146.895775
# 46           Japan   United States   9664.659178
# 47  United Kingdom   United States   6139.224086

# %% [markdown]
# Now we can use the pairs to create the graph, with the first two columns representing the nodes and the last column representing the weight

# %%
import networkx as nx
import matplotlib.pyplot as plt

G_last_year = nx.Graph()

for index, row in trade_last_year.iterrows():
    G_last_year.add_edge(row['export_country'], row['import_country'], weight=row['value'])

# remove isolated vertices (if any)    
remove = [node for node,degree in G_last_year.degree() if degree ==0]
G_last_year.remove_nodes_from(remove)

#Setting size and colours
options = {
     'node_color': 'lightblue',
     'edge_color': 'lightblue',
     'node_size': 1,
     'width': 1,
     'alpha': 1.0}

# %% [markdown]
# ## Draw the graphs to compare
#
# First load back the data:

# %%
import pickle

f = open("graph.pickle", "rb")
G_latest = pickle.load(f)
f.close()

# %%
fig, ax = plt.subplots(3, 2, figsize = (10, 15))
layouts = {"spring": nx.spring_layout, "random": nx.random_layout, "circular": nx.circular_layout}
graphs = {"latest": G_latest, "last year": G_last_year}



for i, (layout_name, layout) in enumerate(layouts.items()):
    for j, (graph_name, graph) in enumerate(graphs.items()):
        pos = layout(graph)
        nx.draw_networkx(graph, pos=pos, ax=ax[i][j], font_size=9,**options)
        plt.tight_layout()
        ax[i][j].set_axis_off()
        ax[i][j].set_title(f"{layout_name} layout for {graph_name} data")

# %%
layouts.items()
# Out:
# dict_items([('spring', <function spring_layout at 0x7fb5907ae3a0>), ('random', <function random_layout at 0x7fb5907ae0d0>), ('circular', <function circular_layout at 0x7fb5907ae160>)])
